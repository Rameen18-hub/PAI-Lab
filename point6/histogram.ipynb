# %%
import cv2
import matplotlib.pyplot as plt

# Read image
img = cv2.imread("blur1.webp")

# Check if image loaded
if img is None:
    print("Error: Image not found. Check file name or path.")
else:

    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Show original image
    plt.imshow(img_rgb)
    plt.title("Original Image")
    plt.axis("off")
    plt.show()

    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Show grayscale image
    plt.subplot(121)
    plt.imshow(gray, cmap="gray")
    plt.title("Grayscale")
    plt.axis("off")

    # Histogram of grayscale
    plt.subplot(122)
    plt.hist(gray.ravel(), 256, [0,256])
    plt.title("Gray Histogram")

    plt.show()

    # RGB Histogram
    colors = ("b","g","r")
    for i,col in enumerate(colors):
        hist = cv2.calcHist([img],[i],None,[256],[0,256])
        plt.plot(hist,color=col)
        plt.xlim([0,256])

    plt.title("RGB Histogram")
    plt.xlabel("Pixel Intensity")
    plt.ylabel("Frequency")
    plt.show()
# Out:
# C:\Users\A.TRADERS\AppData\Local\Temp\ipykernel_4176\1746955729.py:32: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(gray.ravel(), 256, [0,256])
