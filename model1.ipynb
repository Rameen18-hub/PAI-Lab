# %%
[10:14 am, 10/02/2026] Rameen: Great — ab jo final matrix tum ne di hai, usi ko Gauss–Jordan (row operations) se identity banate hain aur saath-saath inverse nikaalte hain. Main steps exam-style likh raha hoon taake tum copy kar sako.

A=
\begin{bmatrix}
3 & 2 & 1 & 5 & 3\\
2 & 6 & 2 & 3 & 1\\
-1 & 2 & 3 & -5 & 0\\
3 & 2 & 8 & 8 & 3\\
2 & 0 & 2 & 3 & 8
\end{bmatrix}


---

1️⃣ Augmented Matrix 

\left[
\begin{array}{ccccc|ccccc}
3&2&1&5&3 & 1&0&0&0&0\\
2&6&2&3&1 & 0&1&0&0&0\\
-1&2&3&-5&0 & 0&0&1&0&0\\
3&2&8&8&3 & 0&0&0&1&0\\
2&0&2&3&8 & 0&0&0&0&1
\end{array}
\right]


---

2️⃣ First pivot = 1 (Row 3 best hai)

Row 3 already starts with −1, is liye:

R_3 \to -R_3

R_3 = [1,\,-2,\,-3,\,5,\,0 \mid 0,0,-1,0,0]

Swap karke upar le aate hain:

R_1 \leftrightarrow R_3

\left[
\begin{array}{ccccc…
[6:16 pm, 14/02/2026] Rameen: import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier


train = pd.read_csv("train.csv") 
test = pd.read_csv("test.csv")    


def preprocess(df):
 
    df = df.drop(columns=["Name", "Ticket", "Cabin"], errors='ignore')
    

    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].fillna(0)

    categorical_cols = df.select_dtypes(include=['object']).columns
    for col in categorical_cols:
        df[col] = df[col].fillna('Unknown')
   
    df = pd.get_dummies(df, drop_first=True)
    
    return df

y_train = train["Transported"]
X_train = train.drop(columns=["Transported"])

X_train = preprocess(X_train)
X_test = preprocess(test)

X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

preds = model.predict(X_test)
submission = pd.DataFrame({
    "PassengerId": test["PassengerId"],
    "Transported": preds 
})

submission.to_csv("submission.csv", index=False)
